# %%
import pandas as pd 
import numpy as np 
df = pd.read_csv('https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv')

# %%
df.head(2)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
# 1      Mailed check          56.95        1889.5    No
#
# [2 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df['TotalCharges']= pd.to_numeric(df['TotalCharges'] , errors = 'coerce')

# %%
df['TotalCharges'].isna().sum()
# Out:
# np.int64(11)

# %%
df[df['TotalCharges'].isna()]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
df['TotalCharges'] = df['TotalCharges'].fillna(0)

# %%
df['TotalCharges'].isna().sum()
# Out:
# np.int64(0)

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df = df.drop('customerID' , axis = 1)

# %%
df.head(4)
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# 2               No          No          No              No  Month-to-month
# ...

# %%
df.isna().sum().sum()
# Out:
# np.int64(0)

# %%
df['Churn_Flag'] = (df['Churn'] =='Yes').astype(int)

# %%
average = df.groupby('Contract')['Churn_Flag'].mean()

# %%
average
# Out:
# Contract
# Month-to-month    0.427097
# One year          0.112695
# Two year          0.028319
# Name: Churn_Flag, dtype: float64

# %%
averageCitizen = df.groupby('SeniorCitizen')['Churn_Flag'].mean()

# %%
averageCitizen
# Out:
# SeniorCitizen
# 0    0.236062
# 1    0.416813
# Name: Churn_Flag, dtype: float64

# %%
import matplotlib.pyplot as plt 
plt.title('Bargraph')
average.plot(kind = 'bar')
plt.ylabel('Churn Rate')
plt.show()

# %%
averageTech = df.groupby('TechSupport')['Churn_Flag'].mean()
averageTech
# Out:
# TechSupport
# No                     0.416355
# No internet service    0.074050
# Yes                    0.151663
# Name: Churn_Flag, dtype: float64

# %%
plt.title('Bargraph')
averageTech.plot(kind = 'bar')
plt.ylabel('Churn Rate')
plt.show()

# %%
remaining_cols = ['OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                   'StreamingTV', 'StreamingMovies', 'PaymentMethod',
                   'InternetService', 'PaperlessBilling']
for col in remaining_cols:
    
    print(df.groupby(col)['Churn_Flag'].mean())
# Out:
# OnlineSecurity
# No                     0.417667
# No internet service    0.074050
# Yes                    0.146112
# Name: Churn_Flag, dtype: float64
# OnlineBackup
# No                     0.399288
# No internet service    0.074050
# Yes                    0.215315
# Name: Churn_Flag, dtype: float64
# DeviceProtection
# No                     0.391276
# No internet service    0.074050
# Yes                    0.225021
# Name: Churn_Flag, dtype: float64
# StreamingTV
# No                     0.335231
# No internet service    0.074050
# Yes                    0.300702
# Name: Churn_Flag, dtype: float64
# StreamingMovies
# No                     0.336804
# No internet service    0.074050
# Yes                    0.299414
# Name: Churn_Flag, dtype: float64
# PaymentMethod
# Bank transfer (automatic)    0.167098
# Credit card (automatic)      0.152431
# Electronic check             0.452854
# Mailed check                 0.191067
# Name: Churn_Flag, dtype: float64
# InternetService
# ...

# %%
churned = df[df['Churn'] == 'Yes']
stayed = df[df['Churn'] == 'No']
plt.hist(churned['tenure'] , alpha = 0.5 , label = 'churned')
plt.hist(stayed['tenure'] , alpha = 0.5 , label = 'stayed')
plt.legend()
plt.show()

# %%
plt.hist(stayed['MonthlyCharges'] , alpha = 0.5 , label = 'stayed' , density = True)
plt.hist(churned['MonthlyCharges'] , alpha = 0.5 , label = 'churned' , density = True)
plt.legend()
plt.show()

# %%
#feature engineering 
X = df.drop(columns = ['Churn_Flag' , 'Churn' ], axis = 1)
y = df['Churn_Flag']

categorical_columns = X.select_dtypes(include = 'object').columns

# %%
categorical_columns
# Out:
# Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod'],
#       dtype='object')

# %%
numerical_columns = X.select_dtypes(exclude = 'object').columns
numerical_columns
# Out:
# Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X , y ,test_size = 0.2 , stratify = y , random_state = 42)

# %%
print(y_train.value_counts(normalize = True))
y_test.value_counts(normalize = True)
# Out:
# Churn_Flag
# 0    0.734647
# 1    0.265353
# Name: proportion, dtype: float64
# Churn_Flag
# 0    0.734564
# 1    0.265436
# Name: proportion, dtype: float64

# %% [raw]
# from sklearn.preprocessing import StandardScaler , OneHotEncoder
# from sklearn.compose import ColumnTransformer
# preprocessor = ColumnTransformer(transformers = [
# ('num' , StandardScaler() , numeric_columns),
# ('cat' , OneHotEncoder() , categorical_columns)
# ])

# %%
from sklearn.preprocessing import StandardScaler , OneHotEncoder 
from sklearn.compose import ColumnTransformer 
preprocessor = ColumnTransformer(transformers = [
('num' , StandardScaler() , numerical_columns),
('cat' , OneHotEncoder() , categorical_columns) 
])

# %%
from sklearn.pipeline import Pipeline 
from sklearn.linear_model import LogisticRegression 
model = LogisticRegression()

# %%
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression

model = Pipeline([
    ('prep', preprocessor),
    ('clf', LogisticRegression(class_weight='balanced', max_iter=1000, random_state=42))
])

# %%
model.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')),
#                                                  ('cat', OneHotEncoder(),
#                                                   Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV', 'StreamingMovies', 'Contract',
#        'PaperlessBilling', 'PaymentMethod'],
#       dtype='object'))])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000,
#                                     random_state=42))])

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([0, 1, 0, ..., 0, 0, 0], shape=(1409,))

# %%
from sklearn.metrics import classification_report 
print(classification_report(y_test , y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.72      0.80      1035
#            1       0.50      0.78      0.61       374
#
#     accuracy                           0.74      1409
#    macro avg       0.70      0.75      0.71      1409
# weighted avg       0.80      0.74      0.75      1409

# %%
neg = (y_train == 0).sum()
pos = (y_train == 1).sum()
scale_pos_weight = neg/pos

# %%
print(scale_pos_weight)
# Out:
# 2.768561872909699

# %%
# %pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier 
xgb_model = Pipeline([('prep' , preprocessor) , 
                     ('clf' , XGBClassifier(scale_pos_weight = scale_pos_weight , eval_metric = 'logloss'))
                     ])

# %%
xgb_model.fit(X_train , y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   Index(['SeniorCitizen', 'tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')),
#                                                  ('cat', OneHotEncoder(),
#                                                   Index(['gender', 'Partner', 'Dependents', 'PhoneService', 'MultipleLines',
#        'InternetService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
#        'TechSupport', 'StreamingTV...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=None,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
# ...

# %%
y_pred_xg = xgb_model.predict(X_test)
print(classification_report(y_test , y_pred_xg))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.82      1035
#            1       0.53      0.66      0.59       374
#
#     accuracy                           0.75      1409
#    macro avg       0.70      0.72      0.71      1409
# weighted avg       0.78      0.75      0.76      1409

# %%
# %pip install shap
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
X_test_transformed = xgb_model.named_steps['prep'].transform(X_test)

# %%
feature_names = xgb_model.named_steps['prep'].get_feature_names_out()

# %%
#shap - tells why the model made those decisions 
#step1 
xgb = xgb_model.named_steps['clf']

# %%
X_test_transformed = xgb_model.named_steps['prep'].transform(X_test)
feature_names = xgb_model.named_steps['prep'].get_feature_names_out()

# %%
import shap

# %%
explainer = shap.TreeExplainer(xgb)
shap_values = explainer(X_test_transformed)

# %%
shap_values.feature_names = feature_names

# %%
shap.plots.beeswarm(shap_values)

# %%
import numpy as np
import shap

print(np.__version__)
print(shap.__version__)
# Out:
# 2.2.6
# 0.51.0

# %%
pip install --upgrade shap
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
